# %%
import os
import pandas

os.listdir()
# Out:
# ['.ipynb_checkpoints', 'files', 'operatePandas.ipynb', 'pd.py', 'Test.ipynb']

# %%
df1 = pandas.read_csv("files/supermarket.csv")
df1
# Out:
#    ID          Address          City             State Country  Supermarket  \
# 0   1     3666 21st St  San Franciso          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Franciso          CA 94115     USA  Bready Shop
# 2   3      332 Hill St  San Franciso  California 94114     USA  Super River
# 3   4     3995 23rd St  San Franciso          CA 94117     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Franciso        California     USA      Sanchez
# 5   6  551 Alvarado St  San Franciso          CA 94119     USA   Richvalley
#
#    Number of Employees
# 0                    8
# 1                   15
# 2                   25
# 3                   10
# 4                   12
# 5                   20

# %%
df1.set_index("Address")
# Out:
#                  ID          City             State Country  Supermarket  \
# Address
# 3666 21st St      1  San Franciso          CA 94114     USA      Madeira
# 735 Dolores St    2  San Franciso          CA 94115     USA  Bready Shop
# 332 Hill St       3  San Franciso  California 94114     USA  Super River
# 3995 23rd St      4  San Franciso          CA 94117     USA   Ben's Shop
# 1056 Sanchez St   5  San Franciso        California     USA      Sanchez
# 551 Alvarado St   6  San Franciso          CA 94119     USA   Richvalley
#
#                  Number of Employees
# Address
# 3666 21st St                       8
# 735 Dolores St                    15
# 332 Hill St                       25
# 3995 23rd St                      10
# 1056 Sanchez St                   12
# 551 Alvarado St                   20

# %%
df1 = pandas.read_csv("files/supermarket.csv", index_col = "Address")

# %%
df1
# Out:
#                  ID          City             State Country  Supermarket  \
# Address
# 3666 21st St      1  San Franciso          CA 94114     USA      Madeira
# 735 Dolores St    2  San Franciso          CA 94115     USA  Bready Shop
# 332 Hill St       3  San Franciso  California 94114     USA  Super River
# 3995 23rd St      4  San Franciso          CA 94117     USA   Ben's Shop
# 1056 Sanchez St   5  San Franciso        California     USA      Sanchez
# 551 Alvarado St   6  San Franciso          CA 94119     USA   Richvalley
#
#                  Number of Employees
# Address
# 3666 21st St                       8
# 735 Dolores St                    15
# 332 Hill St                       25
# 3995 23rd St                      10
# 1056 Sanchez St                   12
# 551 Alvarado St                   20

# %%
df1.drop("3666 21st St", 0)
# Out:
#                  ID          City             State Country  Supermarket  \
# Address
# 735 Dolores St    2  San Franciso          CA 94115     USA  Bready Shop
# 332 Hill St       3  San Franciso  California 94114     USA  Super River
# 3995 23rd St      4  San Franciso          CA 94117     USA   Ben's Shop
# 1056 Sanchez St   5  San Franciso        California     USA      Sanchez
# 551 Alvarado St   6  San Franciso          CA 94119     USA   Richvalley
#
#                  Number of Employees
# Address
# 735 Dolores St                    15
# 332 Hill St                       25
# 3995 23rd St                      10
# 1056 Sanchez St                   12
# 551 Alvarado St                   20

# %%
df1.drop("City", 1)
# Out:
#                  ID             State Country  Supermarket  \
# Address
# 3666 21st St      1          CA 94114     USA      Madeira
# 735 Dolores St    2          CA 94115     USA  Bready Shop
# 332 Hill St       3  California 94114     USA  Super River
# 3995 23rd St      4          CA 94117     USA   Ben's Shop
# 1056 Sanchez St   5        California     USA      Sanchez
# 551 Alvarado St   6          CA 94119     USA   Richvalley
#
#                  Number of Employees
# Address
# 3666 21st St                       8
# 735 Dolores St                    15
# 332 Hill St                       25
# 3995 23rd St                      10
# 1056 Sanchez St                   12
# 551 Alvarado St                   20

# %%
df1.drop(df1.index[0:3], 0)
# Out:
#                  ID          City       State Country Supermarket  \
# Address
# 3995 23rd St      4  San Franciso    CA 94117     USA  Ben's Shop
# 1056 Sanchez St   5  San Franciso  California     USA     Sanchez
# 551 Alvarado St   6  San Franciso    CA 94119     USA  Richvalley
#
#                  Number of Employees
# Address
# 3995 23rd St                      10
# 1056 Sanchez St                   12
# 551 Alvarado St                   20

# %%
df1.drop(df1.columns[1:3], 1)
# Out:
#                  ID Country  Supermarket  Number of Employees
# Address
# 3666 21st St      1     USA      Madeira                    8
# 735 Dolores St    2     USA  Bready Shop                   15
# 332 Hill St       3     USA  Super River                   25
# 3995 23rd St      4     USA   Ben's Shop                   10
# 1056 Sanchez St   5     USA      Sanchez                   12
# 551 Alvarado St   6     USA   Richvalley                   20

# %%
#Updating and Creating Columns and Rows

# %%
df1["Continent"] = df1.shape[0]*["North America"] #creating a column

# %%
df1
# Out:
#                  ID          City             State Country  Supermarket  \
# Address
# 3666 21st St      1  San Franciso          CA 94114     USA      Madeira
# 735 Dolores St    2  San Franciso          CA 94115     USA  Bready Shop
# 332 Hill St       3  San Franciso  California 94114     USA  Super River
# 3995 23rd St      4  San Franciso          CA 94117     USA   Ben's Shop
# 1056 Sanchez St   5  San Franciso        California     USA      Sanchez
# 551 Alvarado St   6  San Franciso          CA 94119     USA   Richvalley
#
#                  Number of Employees      Continent
# Address
# 3666 21st St                       8  North America
# 735 Dolores St                    15  North America
# 332 Hill St                       25  North America
# 3995 23rd St                      10  North America
# 1056 Sanchez St                   12  North America
# 551 Alvarado St                   20  North America

# %%
df1.shape
# Out:
# (6, 7)

# %%
df1.shape[0] #would give six (rows)
# Out:
# 6

# %%
df1["Continent"] = df1["Country"] + ", " + df1["Continent"] #Updating a column

# %%
df1
# Out:
#                  ID          City             State Country  Supermarket  \
# Address
# 3666 21st St      1  San Franciso          CA 94114     USA      Madeira
# 735 Dolores St    2  San Franciso          CA 94115     USA  Bready Shop
# 332 Hill St       3  San Franciso  California 94114     USA  Super River
# 3995 23rd St      4  San Franciso          CA 94117     USA   Ben's Shop
# 1056 Sanchez St   5  San Franciso        California     USA      Sanchez
# 551 Alvarado St   6  San Franciso          CA 94119     USA   Richvalley
#
#                  Number of Employees           Continent
# Address
# 3666 21st St                       8  USA, North America
# 735 Dolores St                    15  USA, North America
# 332 Hill St                       25  USA, North America
# 3995 23rd St                      10  USA, North America
# 1056 Sanchez St                   12  USA, North America
# 551 Alvarado St                   20  USA, North America

# %%
df1_t = df1.T #tranposes the dataframe
#this is done in ordet to add a new row

# %%
df1_t
# Out:
# Address                    3666 21st St      735 Dolores St  \
# ID                                    1                   2
# City                       San Franciso        San Franciso
# State                          CA 94114            CA 94115
# Country                             USA                 USA
# Supermarket                     Madeira         Bready Shop
# Number of Employees                   8                  15
# Continent            USA, North America  USA, North America
#
# Address                     332 Hill St        3995 23rd St  \
# ID                                    3                   4
# City                       San Franciso        San Franciso
# State                  California 94114            CA 94117
# Country                             USA                 USA
# Supermarket                 Super River          Ben's Shop
# Number of Employees                  25                  10
# Continent            USA, North America  USA, North America
# ...

# %%
df1_t["234 Awolowo View"] = [8, "Ile Ife", "OS 4590", "Nigeria", "Glory to Glory", 34, "Nigeria, Africa"]

# %%
df1_t
# Out:
# Address                    3666 21st St      735 Dolores St  \
# ID                                    1                   2
# City                       San Franciso        San Franciso
# State                          CA 94114            CA 94115
# Country                             USA                 USA
# Supermarket                     Madeira         Bready Shop
# Number of Employees                   8                  15
# Continent            USA, North America  USA, North America
#
# Address                     332 Hill St        3995 23rd St  \
# ID                                    3                   4
# City                       San Franciso        San Franciso
# State                  California 94114            CA 94117
# Country                             USA                 USA
# Supermarket                 Super River          Ben's Shop
# Number of Employees                  25                  10
# Continent            USA, North America  USA, North America
# ...

# %%
df1_t.T
# Out:
#                  ID          City             State  Country     Supermarket  \
# Address
# 3666 21st St      1  San Franciso          CA 94114      USA         Madeira
# 735 Dolores St    2  San Franciso          CA 94115      USA     Bready Shop
# 332 Hill St       3  San Franciso  California 94114      USA     Super River
# 3995 23rd St      4  San Franciso          CA 94117      USA      Ben's Shop
# 1056 Sanchez St   5  San Franciso        California      USA         Sanchez
# 551 Alvarado St   6  San Franciso          CA 94119      USA      Richvalley
# 234 Awolowo View  8       Ile Ife           OS 4590  Nigeria  Glory to Glory
#
#                  Number of Employees           Continent
# Address
# 3666 21st St                       8  USA, North America
# 735 Dolores St                    15  USA, North America
# 332 Hill St                       25  USA, North America
# 3995 23rd St                      10  USA, North America
# ...

# %%
df1_t.T
# Out:
#                  ID          City             State  Country     Supermarket  \
# Address
# 3666 21st St      1  San Franciso          CA 94114      USA         Madeira
# 735 Dolores St    2  San Franciso          CA 94115      USA     Bready Shop
# 332 Hill St       3  San Franciso  California 94114      USA     Super River
# 3995 23rd St      4  San Franciso          CA 94117      USA      Ben's Shop
# 1056 Sanchez St   5  San Franciso        California      USA         Sanchez
# 551 Alvarado St   6  San Franciso          CA 94119      USA      Richvalley
# 234 Awolowo View  8       Ile Ife           OS 4590  Nigeria  Glory to Glory
#
#                  Number of Employees           Continent
# Address
# 3666 21st St                       8  USA, North America
# 735 Dolores St                    15  USA, North America
# 332 Hill St                       25  USA, North America
# 3995 23rd St                      10  USA, North America
# ...

# %%
df1 = df1_t.T

# %%
df1
# Out:
#                  ID          City             State  Country     Supermarket  \
# Address
# 3666 21st St      1  San Franciso          CA 94114      USA         Madeira
# 735 Dolores St    2  San Franciso          CA 94115      USA     Bready Shop
# 332 Hill St       3  San Franciso  California 94114      USA     Super River
# 3995 23rd St      4  San Franciso          CA 94117      USA      Ben's Shop
# 1056 Sanchez St   5  San Franciso        California      USA         Sanchez
# 551 Alvarado St   6  San Franciso          CA 94119      USA      Richvalley
# 234 Awolowo View  8       Ile Ife           OS 4590  Nigeria  Glory to Glory
#
#                  Number of Employees           Continent
# Address
# 3666 21st St                       8  USA, North America
# 735 Dolores St                    15  USA, North America
# 332 Hill St                       25  USA, North America
# 3995 23rd St                      10  USA, North America
# ...

# %%
from geopy.geocoders import Nominatim

# %%
df1
# Out:
#                  ID          City             State  Country     Supermarket  \
# Address
# 3666 21st St      1  San Franciso          CA 94114      USA         Madeira
# 735 Dolores St    2  San Franciso          CA 94115      USA     Bready Shop
# 332 Hill St       3  San Franciso  California 94114      USA     Super River
# 3995 23rd St      4  San Franciso          CA 94117      USA      Ben's Shop
# 1056 Sanchez St   5  San Franciso        California      USA         Sanchez
# 551 Alvarado St   6  San Franciso          CA 94119      USA      Richvalley
# 234 Awolowo View  8       Ile Ife           OS 4590  Nigeria  Glory to Glory
#
#                  Number of Employees           Continent
# Address
# 3666 21st St                       8  USA, North America
# 735 Dolores St                    15  USA, North America
# 332 Hill St                       25  USA, North America
# 3995 23rd St                      10  USA, North America
# ...

# %%
list(df1.loc[:,"ID"])
# Out:
# [1, 2, 3, 4, 5, 6, 8]

# %%
list(df1.loc["3666 21st St",:])
# Out:
# [1, 'San Franciso', 'CA 94114', 'USA', 'Madeira', 8, 'USA, North America']

# %%
len(df1)
# Out:
# 7

# %%
list = []
for i in range(len(df1)):
    list.append(df1.iloc[i, :])

# %%
range(len(df1))
# Out:
# range(0, 7)

# %%
for i in range(len(df1)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
list[0]
# Out:
# ID                                      1
# City                         San Franciso
# State                            CA 94114
# Country                               USA
# Supermarket                       Madeira
# Number of Employees                     8
# Continent              USA, North America
# Name: 3666 21st St, dtype: object

# %%
list[0][0]
# Out:
# 1

# %%
df1.ID
# Out:
# Address
# 3666 21st St        1
# 735 Dolores St      2
# 332 Hill St         3
# 3995 23rd St        4
# 1056 Sanchez St     5
# 551 Alvarado St     6
# 234 Awolowo View    8
# Name: ID, dtype: object

# %%
df1.loc[:,"ID"]
# Out:
# Address
# 3666 21st St        1
# 735 Dolores St      2
# 332 Hill St         3
# 3995 23rd St        4
# 1056 Sanchez St     5
# 551 Alvarado St     6
# 234 Awolowo View    8
# Name: ID, dtype: object
